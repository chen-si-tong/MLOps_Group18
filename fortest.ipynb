# %%
import tensorflow as tf

# %%
loaded_model = tf.saved_model.load("/Users/chensitong/MLOps/LFM/MLOps_Group18/checkpoint/final_model")
inference = loaded_model.signatures["serving_default"]
# Out:
# 2024-01-16 04:52:14.614557: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
input1 = [100]
input2 = [100]

# %%
input1 = [100]
input2 = [100]
prediction = inference(input_1=tf.constant(input1, dtype=tf.float32), input_2=tf.constant(input2, dtype=tf.float32))
output_tensor = prediction['output_1']
predicted_value = int(output_tensor.numpy()[0][0])

# %%
output_tensor = prediction['output_1']

# %%
predicted_value = int(output_tensor.numpy()[0][0])

# %%
predicted_value
# Out:
# 5
